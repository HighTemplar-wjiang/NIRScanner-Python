# %%
# %matplotlib inline
from NIRS import NIRS
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal

#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = "all"

# %%
def preprocess(raw_data):
    filtered = scipy.signal.savgol_filter(raw_data, window_length=11, polyorder=3)
    filtered = np.gradient(filtered) # First-order gradient
    filtered_red = np.gradient(filtered) # Second-order gradient
    return filtered

# %%
nirs = NIRS()

# %%
nirs.scan()
result_red = nirs.get_scan_results()

# %%
reflectance_red = np.array(result_red["intensity"]) / np.array(result_red["reference"])
filtered_red = preprocess(reflectance_red)

# %%
plt.plot(result_red["wavelength"], filtered_red)
plt.show()

# %%
nirs.scan()
result_red_black = nirs.get_scan_results()

# %%
reflectance_red_black = np.array(result_red_black["intensity"]) / np.array(result_red_black["reference"])
filtered_red_black = preprocess(reflectance_red_black)
plt.plot(result_red["wavelength"], reflectance_red_black)
plt.show()

# %%
nirs.scan()
result_red_black_mix = nirs.get_scan_results()

# %%
reflectance_red_black_mix = np.array(result_red_black_mix["intensity"]) / np.array(result_red_black_mix["reference"])
filtered_red_black_mix = preprocess(reflectance_red_black_mix)
plt.plot(result_red_black_mix["wavelength"], filtered_red_black_mix)

# %%
plt.plot(result_red["wavelength"], filtered_red)
plt.plot(result_red_black["wavelength"], filtered_red_black)
plt.plot(result_red_black_mix["wavelength"], filtered_red_black_mix)

# %%
nirs.scan()
result_roll = nirs.get_scan_results()

# %%
filtered_roll = preprocess(np.array(result_roll["intensity"]) / np.array(result_roll["reference"]))
plt.plot(result_roll["wavelength"], filtered_roll)
